# %%
import pandas as pd
import pymysql as py
from sqlalchemy import create_engine
engine = create_engine(
    "mysql+pymysql://root:nitya@localhost/tourisms"
)
query = """
SELECT *
FROM tourism;
"""

df = pd.read_sql(query, engine)
df_num=df.select_dtypes(include=['int64', 'float64'])
df_num.drop(['AttractionCountryId', 'AttractionRegionId', 'AttractionContinentId',"CountryId", 'RegionId', 'ContinentId','TransactionId','Rating'], axis=1, inplace= True)

# %%
df_num.columns
# Out:
# Index(['AttractionId', 'AttractionCityId', 'AttractionTypeId', 'UserId',
#        'VisitYear', 'VisitMonth', 'VisitModeId', 'CityId'],
#       dtype='object')

# %% [markdown]
# ### it will not take more than 4 columns
